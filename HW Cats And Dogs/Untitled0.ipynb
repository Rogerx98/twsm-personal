# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from tensorflow.keras.utils import array_to_img
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
#function to get images
from os import listdir
def loadImages(path): #modified from stackoverflow: https://stackoverflow.com/questions/36774431/how-to-load-images-from-a-directory-on-the-computer-in-python
    # return array of images
    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = load_img(path + "/" + image)
        loadedImages.append(img)
    return loadedImages

# %%
#load all images and create data splits
test_cat = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/test/cat")
test_dog = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/test/dog")
train_cat = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/train/cat")
train_dog = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/train/dog")
val_cat = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/validation/cat")
val_dog = loadImages("/content/drive/Othercomputers/Mi portátil/Master/GitHub/twsm-PERSONAL/Data/cats_and_dogs_small/validation/dog")

test_img = test_cat + test_dog
train_img = train_cat + train_dog
val_img = val_cat + val_dog

# %%
#turn all images into reshaped arrays
import numpy as np
def get_array_reshaped(input):
  output = []
  for i in input:
    x = img_to_array(i)
    output.append(tf.image.resize(x, (100, 100)))
  return np.array(output)
  
test_arr = get_array_reshaped(test_img)
train_arr = get_array_reshaped(train_img)
val_arr = get_array_reshaped(val_img)

# %%
len(train_arr), len(test_arr), len(val_arr)
# Out:
# (2000, 1000, 1000)
